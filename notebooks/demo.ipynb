# %%
# Add relevant Jupyter notebook extensions 
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# You can double-check your Python path like this...
import sys  
print(sys.path)
# Out:
# ['/Users/mishatunstall-behrens/Library/CloudStorage/OneDrive-Nexus365/1. OXFORD/WORK - OXFORD/3rd Year/B1 - COMPUTATION/1. SCIENTIFIC CODING/PRACTICAL/b1-coding-practical-mt24', '/opt/anaconda3/envs/b1env/lib/python311.zip', '/opt/anaconda3/envs/b1env/lib/python3.11', '/opt/anaconda3/envs/b1env/lib/python3.11/lib-dynload', '', '/opt/anaconda3/envs/b1env/lib/python3.11/site-packages', '/Users/mishatunstall-behrens/Library/CloudStorage/OneDrive-Nexus365/1. OXFORD/WORK - OXFORD/3rd Year/B1 - COMPUTATION/1. SCIENTIFIC CODING/PRACTICAL/b1-coding-practical-mt24', '/Users/mishatunstall-behrens/Library/CloudStorage/OneDrive-Nexus365/1. OXFORD/WORK - OXFORD/3rd Year/B1 - COMPUTATION/1. SCIENTIFIC CODING/PRACTICAL/b1-coding-practical-mt24']

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
import sys
import os
# Ensure the parent directory is in sys.path for uuv_mission imports
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)

# Import relevant modules
from uuv_mission.dynamic import Submarine, Mission, ClosedLoop
from uuv_mission.control import PDController
sub = Submarine()

# Instantiate your controller (depending on your implementation)
controller = PDController()
closed_loop = ClosedLoop(sub, controller)
mission = Mission.from_csv("../data/mission.csv") # You must implement this method in the Mission class

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)

# %%
import sys
import os
# Add the parent directory to the path so uuv_mission can be imported
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
